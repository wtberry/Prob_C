# %% [markdown]
# # Homework06
#
# ## 1. What is wrong with the following code and how would you fix it?
#
# ```C++
# #ifndef PROJECTILE_H
# #define PROJECTILE_H
# class Projectile {
# private:
# double position;
# double speed;
# public:
# Projectile(double speed, double velocity);
# virtual  ̃Projectile();
# double getSpeed() const;
# double getVelocity() const;
# } // end of Projecile class
# #endif
# ```
# It is missing the semicolon at the end of the declaration after }. add it.
#
# ## 2. The following is the definition of the constructor for the Projectile class above, but there are three things wrong with it. What are they and how would you fix them?
#
# ```C++
#
# Projectile(int speed, int velocity) {
# this.x = x;
# this.y = y;
# } // end of constructor
# ```
#
# wrong variable names, and reference operator. use -> instead of ., and need to add signiture of class name.
#
# ```C++
# Projectile::Projectile(double speed, double velocity) {
# this->speed = speed;
# this->velocity = velocity;
# } // end of constructor
#
# ```
#
# ## 3. Describe each of the following methods.
#
# 1. `int* method(int* arg);`
# > method to return pointer to int, and input pointer to int. might modify the class.
# 2. `const int* method(int* arg);`
# > returns pointer to constant int, might modify the class, and input is pointer to int arg.
# 3. `const int* const method(int* arg);`
# > returns constant pointer to constant int, might modify class and inputs pointer to int arg.
# 4. `const int* const method(const int* arg);`
# > returns constant pointer to constant int, input pointer to constant int. might modify the class.
# 5. `const int* const method(const int* arg) const;`
# > returns consatnt pointer to constant int, input pointer to constant int. Won't modify the class.
#
# ## 4. In what ways are C++ strings better than C strings? In what ways are C strings better than C++ strings?
# - C++ strings are better, in a way that it has useful methods such as .length, and it is string object just like java string, and it is safer.
# - C strings are better when you're writing super light weight code, or using standard C++ library some of which only accepts C string as argument.
#
# ## 5. What is the difference between a pointer and a reference?
#
# - Pointer needs dereferencing operation to get the value stored in the variable, however reference automattically dereference and return value when needed, which makes it convenient for passing for methods.
# - On the other hand, it's better practice to use pointer to declare new heap data, since it has to be deleted after its use.
#
# ## 6. What is a destructor for?
